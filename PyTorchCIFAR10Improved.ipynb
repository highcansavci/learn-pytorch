# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from datetime import datetime

# %%
transformer_train = torchvision.transforms.Compose([
    # torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomCrop(32, padding=4),
    torchvision.transforms.RandomHorizontalFlip(p=0.5),
    # torchvision.transforms.RandomRotation(degrees=15),
    torchvision.transforms.RandomAffine(0, translate=(0.1, 0.1)),
    # torchvision.transforms.RandomPerspective(),
    transforms.ToTensor()
])

train_dataset = torchvision.datasets.CIFAR10(
    root='.',
    train=True,
    transform=transformer_train,
    download=True
)

test_dataset = torchvision.datasets.CIFAR10(
    root='.',
    train=False,
    transform=transforms.ToTensor(),
    download=True
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Files already downloaded and verified

# %%
train_dataset.data
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
train_dataset.data.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_dataset.targets
# Out:
# [6,
#  9,
#  9,
#  4,
#  1,
#  1,
#  2,
#  7,
#  8,
#  3,
#  4,
#  7,
#  7,
#  2,
#  9,
#  9,
#  9,
#  3,
#  2,
#  6,
#  4,
#  3,
#  6,
#  6,
#  2,
#  6,
#  3,
#  5,
#  4,
#  0,
#  0,
#  9,
#  1,
#  3,
#  4,
#  0,
#  3,
#  7,
#  3,
#  3,
#  5,
#  2,
#  2,
#  7,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  9,
#  5,
#  7,
#  9,
#  2,
#  2,
#  5,
#  2,
#  4,
#  3,
#  1,
#  1,
#  8,
#  2,
#  1,
#  1,
#  4,
#  9,
#  7,
#  8,
#  5,
#  9,
#  6,
#  7,
#  3,
#  1,
#  9,
#  0,
#  3,
#  1,
#  3,
#  5,
#  4,
#  5,
#  7,
#  7,
#  4,
#  7,
#  9,
#  4,
#  2,
#  3,
#  8,
#  0,
#  1,
#  6,
#  1,
#  1,
#  4,
#  1,
#  8,
#  3,
#  9,
#  6,
#  6,
#  1,
#  8,
#  5,
#  2,
#  9,
#  9,
#  8,
#  1,
#  7,
#  7,
#  0,
#  0,
#  6,
#  9,
#  1,
#  2,
#  2,
#  9,
#  2,
#  6,
#  6,
#  1,
#  9,
#  5,
#  0,
#  4,
#  7,
#  6,
#  7,
#  1,
#  8,
#  1,
#  1,
#  2,
#  8,
#  1,
#  3,
#  3,
#  6,
#  2,
#  4,
#  9,
#  9,
#  5,
#  4,
#  3,
#  6,
#  7,
#  4,
#  6,
#  8,
#  5,
#  5,
#  4,
#  3,
#  1,
#  8,
#  4,
#  7,
#  6,
#  0,
#  9,
#  5,
#  1,
#  3,
#  8,
#  2,
#  7,
#  5,
#  3,
#  4,
#  1,
#  5,
#  7,
#  0,
#  4,
#  7,
#  5,
#  5,
#  1,
#  0,
#  9,
#  6,
#  9,
#  0,
#  8,
#  7,
#  8,
#  8,
#  2,
#  5,
#  2,
#  3,
#  5,
#  0,
#  6,
#  1,
#  9,
#  3,
#  6,
#  9,
#  1,
#  3,
#  9,
#  6,
#  6,
#  7,
#  1,
#  0,
#  9,
#  5,
#  8,
#  5,
#  2,
#  9,
#  0,
#  8,
#  8,
#  0,
#  6,
#  9,
#  1,
#  1,
#  6,
#  3,
#  7,
#  6,
#  6,
#  0,
#  6,
#  6,
#  1,
#  7,
#  1,
#  5,
#  8,
#  3,
#  6,
#  6,
#  8,
#  6,
#  8,
#  4,
#  6,
#  6,
#  1,
#  3,
#  8,
#  3,
#  4,
#  1,
#  7,
#  1,
#  3,
#  8,
#  5,
#  1,
#  1,
#  4,
#  0,
#  9,
#  3,
#  7,
#  4,
#  9,
#  9,
#  2,
#  4,
#  9,
#  9,
#  1,
#  0,
#  5,
#  9,
#  0,
#  8,
#  2,
#  1,
#  2,
#  0,
#  5,
#  6,
#  3,
#  2,
#  7,
#  8,
#  8,
#  6,
#  0,
#  7,
#  9,
#  4,
#  5,
#  6,
#  4,
#  2,
#  1,
#  1,
#  2,
#  1,
#  5,
#  9,
#  9,
#  0,
#  8,
#  4,
#  1,
#  1,
#  6,
#  3,
#  3,
#  9,
#  0,
#  7,
#  9,
#  7,
#  7,
#  9,
#  1,
#  5,
#  1,
#  6,
#  6,
#  8,
#  7,
#  1,
#  3,
#  0,
#  3,
#  3,
#  2,
#  4,
#  5,
#  7,
#  5,
#  9,
#  0,
#  3,
#  4,
#  0,
#  4,
#  4,
#  6,
#  0,
#  0,
#  6,
#  6,
#  0,
#  8,
#  1,
#  6,
#  2,
#  9,
#  2,
#  5,
#  9,
#  6,
#  7,
#  4,
#  1,
#  8,
#  7,
#  3,
#  6,
#  9,
#  3,
#  0,
#  4,
#  0,
#  5,
#  1,
#  0,
#  3,
#  4,
#  8,
#  5,
#  4,
#  7,
#  2,
#  3,
#  9,
#  7,
#  6,
#  7,
#  1,
#  4,
#  7,
#  0,
#  1,
#  7,
#  3,
#  1,
#  8,
#  4,
#  4,
#  2,
#  0,
#  2,
#  2,
#  0,
#  0,
#  9,
#  0,
#  9,
#  6,
#  8,
#  2,
#  7,
#  7,
#  4,
#  0,
#  3,
#  0,
#  8,
#  9,
#  4,
#  2,
#  7,
#  2,
#  5,
#  2,
#  5,
#  1,
#  9,
#  4,
#  8,
#  5,
#  1,
#  7,
#  4,
#  4,
#  0,
#  6,
#  9,
#  0,
#  7,
#  8,
#  8,
#  9,
#  9,
#  3,
#  3,
#  4,
#  0,
#  4,
#  5,
#  6,
#  6,
#  0,
#  1,
#  0,
#  8,
#  0,
#  4,
#  8,
#  8,
#  1,
#  5,
#  2,
#  6,
#  8,
#  1,
#  0,
#  0,
#  7,
#  7,
#  5,
#  9,
#  6,
#  2,
#  8,
#  3,
#  4,
#  7,
#  3,
#  9,
#  0,
#  1,
#  2,
#  4,
#  8,
#  1,
#  8,
#  6,
#  4,
#  4,
#  5,
#  7,
#  1,
#  3,
#  9,
#  8,
#  0,
#  1,
#  7,
#  5,
#  8,
#  2,
#  8,
#  0,
#  4,
#  1,
#  8,
#  9,
#  8,
#  2,
#  9,
#  9,
#  2,
#  7,
#  5,
#  7,
#  3,
#  8,
#  8,
#  4,
#  4,
#  2,
#  7,
#  1,
#  6,
#  4,
#  0,
#  4,
#  6,
#  9,
#  7,
#  6,
#  2,
#  5,
#  5,
#  1,
#  7,
#  2,
#  2,
#  2,
#  9,
#  5,
#  4,
#  2,
#  7,
#  8,
#  1,
#  3,
#  4,
#  3,
#  7,
#  6,
#  9,
#  8,
#  0,
#  6,
#  0,
#  2,
#  2,
#  2,
#  1,
#  8,
#  4,
#  0,
#  1,
#  8,
#  8,
#  1,
#  5,
#  7,
#  6,
#  4,
#  5,
#  8,
#  7,
#  1,
#  9,
#  1,
#  9,
#  8,
#  4,
#  7,
#  3,
#  8,
#  8,
#  2,
#  6,
#  6,
#  7,
#  1,
#  6,
#  8,
#  1,
#  9,
#  7,
#  8,
#  3,
#  0,
#  1,
#  0,
#  8,
#  8,
#  3,
#  0,
#  0,
#  1,
#  5,
#  0,
#  8,
#  8,
#  7,
#  9,
#  9,
#  0,
#  9,
#  4,
#  1,
#  3,
#  6,
#  6,
#  4,
#  4,
#  7,
#  5,
#  6,
#  0,
#  8,
#  0,
#  3,
#  2,
#  8,
#  4,
#  6,
#  9,
#  9,
#  7,
#  0,
#  3,
#  3,
#  6,
#  7,
#  4,
#  9,
#  1,
#  6,
#  2,
#  7,
#  2,
#  2,
#  0,
#  6,
#  7,
#  5,
#  7,
#  6,
#  8,
#  9,
#  0,
#  9,
#  4,
#  4,
#  7,
#  0,
#  9,
#  4,
#  9,
#  6,
#  9,
#  4,
#  5,
#  7,
#  9,
#  2,
#  4,
#  5,
#  1,
#  4,
#  3,
#  9,
#  6,
#  5,
#  6,
#  9,
#  3,
#  3,
#  5,
#  0,
#  7,
#  2,
#  1,
#  3,
#  6,
#  4,
#  0,
#  0,
#  2,
#  5,
#  0,
#  1,
#  0,
#  2,
#  3,
#  9,
#  8,
#  4,
#  9,
#  8,
#  0,
#  2,
#  6,
#  4,
#  4,
#  0,
#  1,
#  8,
#  8,
#  3,
#  6,
#  9,
#  6,
#  6,
#  7,
#  8,
#  2,
#  4,
#  5,
#  7,
#  6,
#  5,
#  3,
#  0,
#  5,
#  0,
#  5,
#  0,
#  8,
#  2,
#  6,
#  7,
#  3,
#  8,
#  2,
#  1,
#  7,
#  6,
#  7,
#  1,
#  0,
#  9,
#  5,
#  5,
#  0,
#  1,
#  7,
#  6,
#  9,
#  0,
#  4,
#  7,
#  7,
#  1,
#  5,
#  9,
#  4,
#  0,
#  8,
#  5,
#  9,
#  9,
#  6,
#  7,
#  1,
#  8,
#  3,
#  2,
#  3,
#  8,
#  2,
#  2,
#  4,
#  6,
#  0,
#  0,
#  5,
#  3,
#  8,
#  2,
#  3,
#  7,
#  2,
#  9,
#  3,
#  8,
#  7,
#  8,
#  2,
#  7,
#  9,
#  0,
#  2,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  6,
#  2,
#  3,
#  2,
#  8,
#  0,
#  5,
#  5,
#  1,
#  4,
#  5,
#  6,
#  6,
#  2,
#  7,
#  0,
#  1,
#  7,
#  7,
#  8,
#  2,
#  9,
#  2,
#  2,
#  4,
#  2,
#  1,
#  1,
#  1,
#  6,
#  6,
#  6,
#  5,
#  1,
#  1,
#  7,
#  0,
#  4,
#  3,
#  3,
#  7,
#  1,
#  2,
#  3,
#  5,
#  5,
#  5,
#  6,
#  1,
#  4,
#  3,
#  7,
#  8,
#  8,
#  3,
#  6,
#  6,
#  2,
#  3,
#  0,
#  9,
#  4,
#  3,
#  8,
#  0,
#  0,
#  1,
#  1,
#  5,
#  4,
#  9,
#  3,
#  1,
#  8,
#  9,
#  3,
#  9,
#  9,
#  2,
#  9,
#  4,
#  8,
#  2,
#  9,
#  8,
#  8,
#  1,
#  5,
#  3,
#  6,
#  8,
#  7,
#  6,
#  9,
#  8,
#  0,
#  6,
#  4,
#  0,
#  0,
#  2,
#  5,
#  8,
#  2,
#  0,
#  2,
#  7,
#  6,
#  9,
#  7,
#  1,
#  5,
#  5,
#  6,
#  6,
#  3,
#  6,
#  2,
#  4,
#  7,
#  0,
#  5,
#  6,
#  4,
#  6,
#  5,
#  2,
#  4,
#  6,
#  1,
#  6,
#  0,
#  4,
#  0,
#  3,
#  1,
#  8,
#  5,
#  4,
#  4,
#  1,
#  7,
#  3,
#  9,
#  4,
#  7,
#  9,
#  7,
#  3,
#  7,
#  2,
#  8,
#  4,
#  6,
#  6,
#  1,
#  2,
#  9,
#  0,
#  4,
#  8,
#  7,
#  3,
#  9,
#  8,
#  7,
#  7,
#  0,
#  2,
#  4,
#  1,
#  1,
#  4,
#  1,
#  5,
#  4,
#  0,
#  5,
#  6,
#  2,
#  8,
#  5,
#  0,
#  2,
#  1,
#  3,
#  5,
#  7,
#  3,
#  5,
#  1,
#  3,
#  5,
#  ...]

# %%
K = len(set(train_dataset.targets))
print(f"Number of classes: {K}")
# Out:
# Number of classes: 10

# %%
# Data Loader
# Useful because it automatically generates batches in the training loop and takes care of shuffling

batch_size = 128

train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
train_dataset_fixed = torchvision.datasets.CIFAR10(
    root='.',
    train=True,
    transform=transforms.ToTensor(),
    download=True
)

train_loader_fixed = torch.utils.data.DataLoader(
    dataset=train_dataset_fixed,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Files already downloaded and verified

# %%
tmp_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                         batch_size=1,
                                         shuffle=True)

for x, y in tmp_loader:
  print(x)
  print(x.shape)
  print(y.shape)
  break
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9961, 0.9961, 0.9961],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9961, 0.9961, 0.9961],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9922, 0.9922, 0.9922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.9961, 0.9961, 0.9961],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]])
# torch.Size([1, 3, 32, 32])
# torch.Size([1])

# %%
class CNN(nn.Module):
  def __init__(self, num_of_classes):
    super(CNN, self).__init__()
    self.conv1 = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        nn.MaxPool2d(2)
    ) 

    self.conv2 = nn.Sequential(
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(64),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(2)
    )

    self.conv3 = nn.Sequential(
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(128),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(128),
        nn.MaxPool2d(2)
    )

    self.fc1 = nn.Linear(128 * 4 * 4, 1024)
    self.fc2 = nn.Linear(1024, K)
  
  def forward(self, X):
    X = self.conv1(X)
    X = self.conv2(X)
    X = self.conv3(X)
    X = X.view(X.size(0), -1)
    X = F.dropout(X, p=0.5)
    X = F.relu(self.fc1(X))
    X = F.dropout(X, p=0.2)
    X = self.fc2(X)
    return X

# %%
model = CNN(K)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)
# Out:
# cuda:0
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
def batch_gd(model, criterion, optimizer, train_loader, test_loader, epochs):
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for i in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    for inputs, targets in train_loader:
      # move data to GPU
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      # Backward and Optimize
      loss.backward()
      optimizer.step()
      
      train_loss.append(loss.item())

    train_losses[i] = np.mean(train_loss)

    model.eval()
    test_loss = []
    for inputs, targets in test_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      test_loss.append(loss.item())
    
    test_losses[i] = np.mean(test_loss)

    dt = datetime.now() - t0
    print(f"Epoch: {i+1} / {epochs}, Train Loss: {train_losses[i]:.4f}, Test Loss: {test_losses[i]:.4f}, Duration: {dt}")
  
  return train_losses, test_losses

# %%
train_losses, test_losses = batch_gd(model, criterion, optimizer, train_loader, test_loader, epochs=80)
# Out:
# Epoch: 1 / 80, Train Loss: 1.4448, Test Loss: 1.2237, Duration: 0:00:34.976378
# Epoch: 2 / 80, Train Loss: 1.0183, Test Loss: 0.9147, Duration: 0:00:29.042780
# Epoch: 3 / 80, Train Loss: 0.8537, Test Loss: 0.8087, Duration: 0:00:29.212508
# Epoch: 4 / 80, Train Loss: 0.7689, Test Loss: 0.7493, Duration: 0:00:27.884865
# Epoch: 5 / 80, Train Loss: 0.6919, Test Loss: 0.7099, Duration: 0:00:29.835414
# Epoch: 6 / 80, Train Loss: 0.6473, Test Loss: 0.7074, Duration: 0:00:27.993165
# Epoch: 7 / 80, Train Loss: 0.6079, Test Loss: 0.6039, Duration: 0:00:27.982789
# Epoch: 8 / 80, Train Loss: 0.5746, Test Loss: 0.6215, Duration: 0:00:28.683951
# Epoch: 9 / 80, Train Loss: 0.5551, Test Loss: 0.6281, Duration: 0:00:27.989448
# Epoch: 10 / 80, Train Loss: 0.5258, Test Loss: 0.5645, Duration: 0:00:27.815828
# Epoch: 11 / 80, Train Loss: 0.5114, Test Loss: 0.5293, Duration: 0:00:28.528143
# Epoch: 12 / 80, Train Loss: 0.4861, Test Loss: 0.5205, Duration: 0:00:27.894993
# Epoch: 13 / 80, Train Loss: 0.4728, Test Loss: 0.5452, Duration: 0:00:27.760102
# Epoch: 14 / 80, Train Loss: 0.4605, Test Loss: 0.5029, Duration: 0:00:28.565070
# Epoch: 15 / 80, Train Loss: 0.4531, Test Loss: 0.5028, Duration: 0:00:27.944340
# Epoch: 16 / 80, Train Loss: 0.4365, Test Loss: 0.5089, Duration: 0:00:27.734848
# Epoch: 17 / 80, Train Loss: 0.4193, Test Loss: 0.4804, Duration: 0:00:29.954511
# Epoch: 18 / 80, Train Loss: 0.4103, Test Loss: 0.5013, Duration: 0:00:27.908694
# Epoch: 19 / 80, Train Loss: 0.4025, Test Loss: 0.5280, Duration: 0:00:27.947405
# Epoch: 20 / 80, Train Loss: 0.3905, Test Loss: 0.4652, Duration: 0:00:28.512100
# Epoch: 21 / 80, Train Loss: 0.3833, Test Loss: 0.5036, Duration: 0:00:27.824962
# Epoch: 22 / 80, Train Loss: 0.3750, Test Loss: 0.4710, Duration: 0:00:27.873657
# Epoch: 23 / 80, Train Loss: 0.3694, Test Loss: 0.4554, Duration: 0:00:28.396986
# Epoch: 24 / 80, Train Loss: 0.3583, Test Loss: 0.4667, Duration: 0:00:27.766182
# Epoch: 25 / 80, Train Loss: 0.3546, Test Loss: 0.4561, Duration: 0:00:27.872569
# Epoch: 26 / 80, Train Loss: 0.3467, Test Loss: 0.4483, Duration: 0:00:28.496043
# Epoch: 27 / 80, Train Loss: 0.3409, Test Loss: 0.4415, Duration: 0:00:27.718604
# Epoch: 28 / 80, Train Loss: 0.3373, Test Loss: 0.4112, Duration: 0:00:27.871356
# Epoch: 29 / 80, Train Loss: 0.3289, Test Loss: 0.4289, Duration: 0:00:28.303220
# Epoch: 30 / 80, Train Loss: 0.3233, Test Loss: 0.4231, Duration: 0:00:29.193479
# Epoch: 31 / 80, Train Loss: 0.3146, Test Loss: 0.4248, Duration: 0:00:28.038660
# Epoch: 32 / 80, Train Loss: 0.3050, Test Loss: 0.4346, Duration: 0:00:27.990328
# Epoch: 33 / 80, Train Loss: 0.3041, Test Loss: 0.4375, Duration: 0:00:28.162731
# Epoch: 34 / 80, Train Loss: 0.2995, Test Loss: 0.4312, Duration: 0:00:27.920792
# Epoch: 35 / 80, Train Loss: 0.2945, Test Loss: 0.4292, Duration: 0:00:27.786337
# Epoch: 36 / 80, Train Loss: 0.2902, Test Loss: 0.4161, Duration: 0:00:28.249978
# Epoch: 37 / 80, Train Loss: 0.2851, Test Loss: 0.4049, Duration: 0:00:27.849892
# Epoch: 38 / 80, Train Loss: 0.2830, Test Loss: 0.3956, Duration: 0:00:27.626033
# Epoch: 39 / 80, Train Loss: 0.2807, Test Loss: 0.4187, Duration: 0:00:28.223118
# Epoch: 40 / 80, Train Loss: 0.2734, Test Loss: 0.4120, Duration: 0:00:27.811400
# Epoch: 41 / 80, Train Loss: 0.2745, Test Loss: 0.3940, Duration: 0:00:27.834445
# Epoch: 42 / 80, Train Loss: 0.2674, Test Loss: 0.3875, Duration: 0:00:28.607512
# Epoch: 43 / 80, Train Loss: 0.2604, Test Loss: 0.4153, Duration: 0:00:29.185248
# Epoch: 44 / 80, Train Loss: 0.2597, Test Loss: 0.4054, Duration: 0:00:27.849431
# Epoch: 45 / 80, Train Loss: 0.2547, Test Loss: 0.3960, Duration: 0:00:28.232455
# Epoch: 46 / 80, Train Loss: 0.2541, Test Loss: 0.3911, Duration: 0:00:27.860018
# Epoch: 47 / 80, Train Loss: 0.2492, Test Loss: 0.4087, Duration: 0:00:27.743425
# Epoch: 48 / 80, Train Loss: 0.2464, Test Loss: 0.4115, Duration: 0:00:28.493634
# Epoch: 49 / 80, Train Loss: 0.2448, Test Loss: 0.3942, Duration: 0:00:27.867743
# Epoch: 50 / 80, Train Loss: 0.2410, Test Loss: 0.3936, Duration: 0:00:27.825656
# Epoch: 51 / 80, Train Loss: 0.2402, Test Loss: 0.4022, Duration: 0:00:28.214408
# Epoch: 52 / 80, Train Loss: 0.2354, Test Loss: 0.3774, Duration: 0:00:27.879177
# Epoch: 53 / 80, Train Loss: 0.2332, Test Loss: 0.4024, Duration: 0:00:27.846294
# Epoch: 54 / 80, Train Loss: 0.2340, Test Loss: 0.3964, Duration: 0:00:28.350566
# Epoch: 55 / 80, Train Loss: 0.2259, Test Loss: 0.3850, Duration: 0:00:27.851268
# Epoch: 56 / 80, Train Loss: 0.2277, Test Loss: 0.4067, Duration: 0:00:28.991387
# Epoch: 57 / 80, Train Loss: 0.2217, Test Loss: 0.3846, Duration: 0:00:28.453838
# Epoch: 58 / 80, Train Loss: 0.2233, Test Loss: 0.3935, Duration: 0:00:27.789609
# Epoch: 59 / 80, Train Loss: 0.2211, Test Loss: 0.3733, Duration: 0:00:27.748919
# Epoch: 60 / 80, Train Loss: 0.2138, Test Loss: 0.3952, Duration: 0:00:28.436966
# Epoch: 61 / 80, Train Loss: 0.2139, Test Loss: 0.4059, Duration: 0:00:27.633154
# Epoch: 62 / 80, Train Loss: 0.2131, Test Loss: 0.3956, Duration: 0:00:27.829227
# Epoch: 63 / 80, Train Loss: 0.2079, Test Loss: 0.3922, Duration: 0:00:28.388692
# Epoch: 64 / 80, Train Loss: 0.2091, Test Loss: 0.4074, Duration: 0:00:27.916710
# Epoch: 65 / 80, Train Loss: 0.2023, Test Loss: 0.3929, Duration: 0:00:27.956737
# Epoch: 66 / 80, Train Loss: 0.2043, Test Loss: 0.3883, Duration: 0:00:28.384790
# Epoch: 67 / 80, Train Loss: 0.2019, Test Loss: 0.4015, Duration: 0:00:27.925960
# Epoch: 68 / 80, Train Loss: 0.2078, Test Loss: 0.3887, Duration: 0:00:27.873776
# Epoch: 69 / 80, Train Loss: 0.1965, Test Loss: 0.4056, Duration: 0:00:28.337112
# Epoch: 70 / 80, Train Loss: 0.1962, Test Loss: 0.3988, Duration: 0:00:29.414033
# Epoch: 71 / 80, Train Loss: 0.1953, Test Loss: 0.4003, Duration: 0:00:27.807296
# Epoch: 72 / 80, Train Loss: 0.1956, Test Loss: 0.3969, Duration: 0:00:28.441884
# Epoch: 73 / 80, Train Loss: 0.1940, Test Loss: 0.3977, Duration: 0:00:27.814568
# Epoch: 74 / 80, Train Loss: 0.1930, Test Loss: 0.3920, Duration: 0:00:27.883690
# Epoch: 75 / 80, Train Loss: 0.1859, Test Loss: 0.3975, Duration: 0:00:28.406370
# Epoch: 76 / 80, Train Loss: 0.1887, Test Loss: 0.4056, Duration: 0:00:27.730379
# Epoch: 77 / 80, Train Loss: 0.1890, Test Loss: 0.3938, Duration: 0:00:27.789499
# Epoch: 78 / 80, Train Loss: 0.1869, Test Loss: 0.3936, Duration: 0:00:28.166930
# Epoch: 79 / 80, Train Loss: 0.1818, Test Loss: 0.4135, Duration: 0:00:28.080875
# Epoch: 80 / 80, Train Loss: 0.1826, Test Loss: 0.4015, Duration: 0:00:27.972348

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.legend();

# %%
# Accuracy
model.eval()

n_correct = 0.
n_total = 0.

for inputs, targets in train_loader:
  # move data to GPU
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward Pass
  outputs = model(inputs)

  # Get predictions 
  # torch.max return both max and argmax
  _, predictions = torch.max(outputs, 1)

  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

train_acc = n_correct / n_total

n_correct = 0.
n_total = 0.

for inputs, targets in test_loader:
  # move data to GPU
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward Pass
  outputs = model(inputs)

  # Get predictions 
  # torch.max return both max and argmax
  _, predictions = torch.max(outputs, 1)

  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

test_acc = n_correct / n_total

print(f"Train Accuracy:{train_acc:.4f}, Test Accuracy:{test_acc:.4f}")
# Out:
# Train Accuracy:0.9330, Test Accuracy:0.8766

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.1-py3-none-any.whl (517 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.13.1+cu116)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (4.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (23.0)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.11.1

# %%
# Get all the test predictions in an array and plot confusion matrix

x_test = test_dataset.data
y_test = test_dataset.targets
p_test = np.array([])

for inputs, targets in test_loader:
  # Move data to GPU
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward Pass
  outputs = model(inputs)
  loss = criterion(outputs, targets)

  # Get prediction
  # torch.max return both max and argmax
  _, predictions = torch.max(outputs, 1)

  # Concatenate the predictions
  p_test = np.concatenate((p_test, predictions.cpu().numpy()))

# %%
from torchmetrics import ConfusionMatrix

# %%
# Confusion Matrix
confmat = ConfusionMatrix(task="multiclass", num_classes=10)
confmat(torch.Tensor(p_test), torch.Tensor(y_test))
# Out:
# tensor([[869,   5,  29,  11,   2,   4,   1,   4,  61,  14],
#         [  3, 948,   0,   2,   1,   0,   0,   0,   9,  37],
#         [ 26,   1, 819,  46,  27,  43,  25,   5,   7,   1],
#         [ 18,   2,  14, 763,  22, 150,  14,   7,   7,   3],
#         [  6,   1,  23,  42, 835,  52,  15,  20,   5,   1],
#         [ 11,   1,  10,  65,   9, 891,   2,   4,   2,   5],
#         [  8,   1,  14,  35,   7,  14, 910,   2,   4,   5],
#         [ 10,   0,   5,  19,  17,  73,   1, 871,   2,   2],
#         [ 19,   7,   2,   5,   0,   3,   1,   0, 954,   9],
#         [  6,  33,   2,   4,   1,   2,   1,   2,  15, 934]])

# %%
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
p_test = p_test.astype(np.uint8)
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i].reshape(32, 32, 3))
plt.title(f"True Label: {labels[y_test[i]]}, Predicted Label: {labels[p_test[i]]}");

# %%
from torchsummary import summary 
summary(model, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#               ReLU-2           [-1, 32, 32, 32]               0
#        BatchNorm2d-3           [-1, 32, 32, 32]              64
#             Conv2d-4           [-1, 32, 32, 32]           9,248
#               ReLU-5           [-1, 32, 32, 32]               0
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#          MaxPool2d-7           [-1, 32, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          18,496
#               ReLU-9           [-1, 64, 16, 16]               0
#       BatchNorm2d-10           [-1, 64, 16, 16]             128
#            Conv2d-11           [-1, 64, 16, 16]          36,928
#              ReLU-12           [-1, 64, 16, 16]               0
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
#         MaxPool2d-14             [-1, 64, 8, 8]               0
#            Conv2d-15            [-1, 128, 8, 8]          73,856
#              ReLU-16            [-1, 128, 8, 8]               0
#       BatchNorm2d-17            [-1, 128, 8, 8]             256
#            Conv2d-18            [-1, 128, 8, 8]         147,584
#              ReLU-19            [-1, 128, 8, 8]               0
#       BatchNorm2d-20            [-1, 128, 8, 8]             256
#         MaxPool2d-21            [-1, 128, 4, 4]               0
#            Linear-22                 [-1, 1024]       2,098,176
#            Linear-23                   [-1, 10]          10,250
# ================================================================
# Total params: 2,396,330
# Trainable params: 2,396,330
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.74
# Params size (MB): 9.14
# Estimated Total Size (MB): 11.90
# ----------------------------------------------------------------
